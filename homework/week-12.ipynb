# %% [markdown]
# <a href="https://colab.research.google.com/github/natepearsall/git-test/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt
plt.pie(slices, labels=labels, autopct='%1.1f%%', startangle=90)

plt.title("Distribution of Values")


plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n, bins=30, color='blue', alpha=0.7)

plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')

plt.show()

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
df = pd.DataFrame({'x': x, 'y': y})

plt.scatter(df['x'], df['y'], label='Data Points')

slope, intercept = np.polyfit(df['x'], df['y'], 1)

trendline = intercept + slope * df['x']

plt.plot(df['x'], trendline, color='red', label='Trendline')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatterplot with Trendline')

plt.legend()

plt.show()
